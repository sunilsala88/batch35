# %%
import numpy as np
np1=np.arange(25).reshape(5,5)
np1

# %% [markdown]
# dataframe from numpy array

# %%
import pandas as pd
df1=pd.DataFrame(np1,index=['r1','r2','r3','r4','r5'],columns=['c1','c2','c3','c4','c5'])
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df1=pd.DataFrame(np1,index=['r1','r2','r3','r4','r5'],columns=['c1','c2','c3','c4','c5'])
#       3 df1
#
# NameError: name 'np1' is not defined

# %% [markdown]
# dataframe from list of list

# %%
l1=[[1,2,3],[44,55,66],[77,88,99]]
df2=pd.DataFrame(l1,columns=['tsla','amzn','goog'],index=[11,12,13])
df2

# %% [markdown]
# dataframe from dict of list

# %%
dl1=[{"name":'tsla','price':500,'sector':'auto'},
     {"name":'amzn','price':600,'sector':'tech'},
     {"name":'jpmorgan','price':800,'sector':'bank'}]
df3=pd.DataFrame(dl1)
df3

# %% [markdown]
# list of dictionary

# %%
ld1={"name":['tsla','amzn','jpmorgan'],
     'price':[500,600,800],
     'sector':['auto','tech','bank']}
df4=pd.DataFrame(ld1)
df4

# %% [markdown]
# csv

# %%
df5=pd.read_csv('sp500.csv')
df5
# Out:
#                            Name                  Sector   Price    EPS
# 0                     Apple Inc  Information Technology  170.12   9.20
# 1                    Abbvie Inc             Health Care   93.29   5.31
# 2           Abbott Laboratories             Health Care   55.28   2.41
# 3                 Accenture Plc  Information Technology  145.30    NaN
# 4                  Allergan Plc             Health Care  171.81  15.42
# ..                          ...                     ...     ...    ...
# 97   Verizon Communications Inc      Telecommunications   45.85   3.75
# 98     Walgreens Boots Alliance        Consumer Staples   70.25   5.10
# 99        Wells Fargo & Company              Financials   54.02   4.14
# 100             Wal-Mart Stores        Consumer Staples   96.08   4.36
# 101            Exxon Mobil Corp                  Energy   80.31   3.56
#
# [102 rows x 4 columns]

# %%
df5.to_excel('e500.xlsx')

# %%
# !pip3 install openpyxl

# %%
df6=pd.read_excel('e500.xlsx')
df6

# %%
# !pip3 install lxml

# %%
#https://colab.research.google.com/drive/1CslXc80566TtwVgMgjy2yxAr1coyZyOq?usp=sharing

# %%
# !pip3 install requests

# %%
import pandas as pd
import requests

url = 'https://en.wikipedia.org/wiki/NIFTY_50'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

response = requests.get(url, headers=headers)
df7 = pd.read_html(response.text)
df7=df7[1]
# Out:
# /var/folders/gf/2xw81y_n41x8mbjy1d6lp0540000gn/T/ipykernel_68365/1850262373.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df7 = pd.read_html(response.text)

# %%
df7.rename(columns={'Company name':'name','Sector[15]':'sector','Date added[16]':'Date'},inplace=True)

# %%
df7.head(10)

# %%
df7.tail(10)

# %%
df5.info()

# %%
df5.describe()

# %%
df5.shape

# %%
list(df5.columns)

# %%
list(df5.index)

# %% [markdown]
# single column ->series
#
#
# more than 1 column ->dataframe

# %%
df5[['Name','EPS']]
# Out:
#                            Name    EPS
# 0                     Apple Inc   9.20
# 1                    Abbvie Inc   5.31
# 2           Abbott Laboratories   2.41
# 3                 Accenture Plc    NaN
# 4                  Allergan Plc  15.42
# ..                          ...    ...
# 97   Verizon Communications Inc   3.75
# 98     Walgreens Boots Alliance   5.10
# 99        Wells Fargo & Company   4.14
# 100             Wal-Mart Stores   4.36
# 101            Exxon Mobil Corp   3.56
#
# [102 rows x 2 columns]

# %%
df5.Name
# Out:
# 0                       Apple Inc
# 1                      Abbvie Inc
# 2             Abbott Laboratories
# 3                   Accenture Plc
# 4                    Allergan Plc
#                   ...
# 97     Verizon Communications Inc
# 98       Walgreens Boots Alliance
# 99          Wells Fargo & Company
# 100               Wal-Mart Stores
# 101              Exxon Mobil Corp
# Name: Name, Length: 102, dtype: object

# %%
print(df5[df5['Price']>100])
# Out:
#                                Name                  Sector    Price    EPS
# 0                         Apple Inc  Information Technology   170.12   9.20
# 3                     Accenture Plc  Information Technology   145.30    NaN
# 4                      Allergan Plc             Health Care   171.81  15.42
# 6                     Allstate Corp              Financials   100.50   6.79
# 7                             Amgen             Health Care   168.93  12.58
# 8                   Amazon.Com Inc.  Consumer Discretionary  1126.82   3.94
# 10                   Boeing Company             Industrials   265.04   9.75
# 12                       Biogen Inc             Health Care   311.92  21.59
# 14                        Blackrock              Financials   474.05  21.55
# 16             Berkshire Hath Hld B              Financials   181.27   6.29
# 18                  Caterpillar Inc             Industrials   137.37   5.55
# ...

# %%
df5[df5['EPS']>5]
# Out:
#                                Name                  Sector    Price    EPS
# 0                         Apple Inc  Information Technology   170.12   9.20
# 1                        Abbvie Inc             Health Care    93.29   5.31
# 4                      Allergan Plc             Health Care   171.81  15.42
# 6                     Allstate Corp              Financials   100.50   6.79
# 7                             Amgen             Health Care   168.93  12.58
# 9          American Express Company              Financials    93.92   5.22
# 10                   Boeing Company             Industrials   265.04   9.75
# 12                       Biogen Inc             Health Care   311.92  21.59
# 14                        Blackrock              Financials   474.05  21.55
# 16             Berkshire Hath Hld B              Financials   181.27   6.29
# 17                    Citigroup Inc              Financials    71.87   5.19
# ...

# %%
df5[(df5['EPS']>5) & (df5['Price']>200)]
# Out:
#                       Name                  Sector    Price    EPS
# 10          Boeing Company             Industrials   265.04   9.75
# 12              Biogen Inc             Health Care   311.92  21.59
# 14               Blackrock              Financials   474.05  21.55
# 37              Fedex Corp             Industrials   217.75  11.91
# 44        Alphabet Class C  Information Technology  1018.48  29.87
# 45        Alphabet Class A  Information Technology  1034.09  29.87
# 46     Goldman Sachs Group              Financials   238.05  19.20
# 58    Lockheed Martin Corp             Industrials   312.93  12.72
# 65              3M Company             Industrials   232.49   8.95
# 75         Priceline Group  Consumer Discretionary  1762.23  74.45
# 91  Unitedhealth Group Inc             Health Care   209.75   9.60

# %%
df5[(df5['EPS']>5) & (df5['Price']>200)]['Name'].to_list()
# Out:
# ['Boeing Company',
#  'Biogen Inc',
#  'Blackrock',
#  'Fedex Corp',
#  'Alphabet Class C',
#  'Alphabet Class A',
#  'Goldman Sachs Group',
#  'Lockheed Martin Corp',
#  '3M Company',
#  'Priceline Group',
#  'Unitedhealth Group Inc']
