# %%
from ib_async import *
util.startLoop()  # uncomment this line when in a notebook

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=98)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=98>
# Error 436, reqId 8: You must specify an allocation (either a single account, group, or profile).
# Canceled order: Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=8, clientId=98, action='BUY', totalQuantity=1, lmtPrice=185.4), orderStatus=OrderStatus(orderId=8, status='Cancelled', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 3, 210108, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 3, 458394, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 436, reqId 8: You must specify an allocation (either a single account, group, or profile).', errorCode=436)], advancedError='')
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=8, clientId=98, action='BUY', totalQuantity=1, lmtPrice=185.4), orderStatus=OrderStatus(orderId=8, status='Cancelled', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 3, 210108, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 3, 458394, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 436, reqId 8: You must specify an allocation (either a single account, group, or profile).', errorCode=436)], advancedError='')
# 2026-03-14 19:39:03.459551
# Error 436, reqId 9: You must specify an allocation (either a single account, group, or profile).
# Canceled order: Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=9, clientId=98, action='BUY', totalQuantity=1, lmtPrice=185.4), orderStatus=OrderStatus(orderId=9, status='Cancelled', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 15, 96748, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 15, 216954, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 436, reqId 9: You must specify an allocation (either a single account, group, or profile).', errorCode=436)], advancedError='')
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=9, clientId=98, action='BUY', totalQuantity=1, lmtPrice=185.4), orderStatus=OrderStatus(orderId=9, status='Cancelled', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 15, 96748, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 15, 216954, tzinfo=datetime.timezone.utc), status='Cancelled', message='Error 436, reqId 9: You must specify an allocation (either a single account, group, or profile).', errorCode=436)], advancedError='')
# 2026-03-14 19:39:15.218031
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; euhmds; apachmds; fundfarm; secdefhk. The following farms are not connected: uscrypto; usfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usopt.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk. The following farms are not connected: usfuture; usfarm.nj.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usopt.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture.nj; usfuture; eufarm; euhmds; apachmds; secdefhk. The following farms are not connected: uscrypto; usfarm.nj; usfarm; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture.nj; usfuture; eufarm; usfarm; euhmds; apachmds; secdefhk. The following farms are not connected: uscrypto; usfarm.nj; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; secdefhk. The following farms are not connected: ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; secdefhk. The following farms are not connected: fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture; eufarm; usfarm; euhmds; apachmds; secdefhk. The following farms are not connected: usfuture.nj; usfarm.nj; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; eufarm; euhmds; apachmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; usfarm; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; secdefhk. The following farms are not connected: fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; eufarm; euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; usfarm; fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; eufarm; euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: usfarm.nj; usfarm; fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture.nj; usfuture; eufarm; usfarm; euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: uscrypto; usfarm.nj; fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture; eufarm; euhmds; apachmds; secdefhk. The following farms are not connected: usfuture.nj; usfarm.nj; usfarm; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture; eufarm; euhmds; apachmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfarm.nj; usfarm; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture; eufarm; euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfarm.nj; usfarm; fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture; eufarm; euhmds; apachmds; fundfarm; ushmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfarm.nj; usfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture; eufarm; euhmds; apachmds; fundfarm; ushmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfarm.nj; usfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; eufarm; euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; usfarm; fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: apachmds; secdefhk. The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; eufarm; euhmds; apachmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; usfarm; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; eufarm; euhmds; apachmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; usfarm; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; euhmds; apachmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; fundfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; eufarm; euhmds; apachmds; ushmds; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; usfarm; fundfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk. The following farms are not connected: usfuture.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk. The following farms are not connected: usfuture.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; eufarm; euhmds; apachmds; fundfarm; secdefhk. The following farms are not connected: uscrypto; usfuture.nj; usfuture; usfarm.nj; usfarm; ushmds.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. All data farms are connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: . The following farms are not connected: hfarm; cashfarm; uscrypto; usfuture.nj; usfuture; usfarm.nj; eufarm; usfarm; euhmds; apachmds; fundfarm; ushmds; secdefhk.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1102, reqId -1: Connectivity between IBKR and Trader Workstation has been restored - data maintained. The following farms are connected: hfarm; cashfarm; usfuture.nj; usfuture; eufarm; euhmds; apachmds; fundfarm; ushmds; secdefhk. The following farms are not connected: uscrypto; usfarm.nj; usfarm.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Error 1100, reqId -1: Connectivity between IBKR and Trader Workstation has been lost.
# Peer closed connection.
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect
# Future exception was never retrieved
# future: <Future finished exception=ConnectionError('Socket disconnect')>
# ConnectionError: Socket disconnect

# %%
import datetime as dt
def order_handler(o):
    print(o)
    print(dt.datetime.now())

ib.newOrderEvent += order_handler
ib.orderStatusEvent += order_handler
ib.cancelOrderEvent += order_handler
import time
time.sleep(1)
ib.placeOrder(Stock('AMZN','SMART','USD'),LimitOrder('BUY',1,185.40))
print('placed order')
ib.run()
# Out:
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=8, clientId=98, action='BUY', totalQuantity=1, lmtPrice=185.4), orderStatus=OrderStatus(orderId=8, status='PendingSubmit', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 3, 210108, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0)], advancedError='')
# 2026-03-14 19:39:03.210512
# placed order

# %%
ib.placeOrder(Stock('AMZN','SMART','USD'),LimitOrder('BUY',1,185.40))
print('placed order')
# Out:
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=9, clientId=98, action='BUY', totalQuantity=1, lmtPrice=185.4), orderStatus=OrderStatus(orderId=9, status='PendingSubmit', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 14, 14, 9, 15, 96748, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0)], advancedError='')
# 2026-03-14 19:39:15.097139
# placed order
