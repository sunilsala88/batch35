# %%
from ib_async import *
util.startLoop()  # uncomment this line when in a notebook

ib = IB()
ib.connect('127.0.0.1', 7497, clientId=93)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=93>
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=12, clientId=93, permId=1041064007, action='BUY', totalQuantity=1.0, lmtPrice=185.4, auxPrice=0.0), orderStatus=OrderStatus(orderId=12, status='PreSubmitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1041064007, parentId=0, lastFillPrice=0.0, clientId=93, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 40, 460073, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 41, 251547, tzinfo=datetime.timezone.utc), status='PreSubmitted', message='', errorCode=0)], advancedError='')
# 2026-03-08 18:57:41.252017
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=12, clientId=93, permId=1041064007, action='BUY', totalQuantity=1.0, lmtPrice=185.4, auxPrice=0.0), orderStatus=OrderStatus(orderId=12, status='Submitted', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1041064007, parentId=0, lastFillPrice=0.0, clientId=93, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 40, 460073, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 41, 251547, tzinfo=datetime.timezone.utc), status='PreSubmitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 41, 253380, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0)], advancedError='')
# 2026-03-08 18:57:41.253564
# Error 202, reqId 12: Order Canceled - reason:
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=12, clientId=93, permId=1041064007, action='BUY', totalQuantity=1.0, lmtPrice=185.4, auxPrice=0.0), orderStatus=OrderStatus(orderId=12, status='Cancelled', filled=0.0, remaining=1.0, avgFillPrice=0.0, permId=1041064007, parentId=0, lastFillPrice=0.0, clientId=93, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 40, 460073, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 41, 251547, tzinfo=datetime.timezone.utc), status='PreSubmitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 41, 253380, tzinfo=datetime.timezone.utc), status='Submitted', message='', errorCode=0), TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 49, 149153, tzinfo=datetime.timezone.utc), status='Cancelled', message='', errorCode=0)], advancedError='')
# 2026-03-08 18:57:49.149725
# Peer closed connection.

# %%
import datetime as dt

def order_handler(o):
    print(o)
    print(dt.datetime.now())



ib.newOrderEvent += order_handler
ib.orderStatusEvent += order_handler
ib.cancelOrderEvent += order_handler
import time
time.sleep(1)
ib.placeOrder(Stock('AMZN','SMART','USD'),LimitOrder('BUY',1,185.40))
print('placed order')
ib.run()
# Out:
# Trade(contract=Stock(symbol='AMZN', exchange='SMART', currency='USD'), order=LimitOrder(orderId=12, clientId=93, action='BUY', totalQuantity=1, lmtPrice=185.4), orderStatus=OrderStatus(orderId=12, status='PendingSubmit', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 3, 8, 13, 27, 40, 460073, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0)], advancedError='')
# 2026-03-08 18:57:40.460441
# placed order
