# %%
from ib_async import *
util.startLoop()  # uncomment this line when in a notebook

ib = IB()
client_id=91
ib.connect('127.0.0.1', 7497, clientId=client_id)
# Out:
# <IB connected to 127.0.0.1:7497 clientId=91>
# Error 202, reqId 4: Order Canceled - reason:
# Error 202, reqId 6: Order Canceled - reason:
# Error 202, reqId 8: Order Canceled - reason:
# Peer closed connection.

# %%
name='ETH'
contract_obj=Crypto(name,'PAXOS','USD')
contract_obj=ib.qualifyContracts(contract_obj)[0]
contract_obj

account_no='DUH316001'
ord_validity='IOC'
# ord=MarketOrder(action='BUY',totalQuantity=1)
ord=Order(orderId=ib.client.getReqId(),orderType='LMT',action='BUY',account=account_no,tif=ord_validity,totalQuantity=1.000,lmtPrice=2190)
trade=ib.placeOrder(contract_obj,ord)
trade
# Out:
# Trade(contract=Crypto(conId=495759171, symbol='ETH', exchange='PAXOS', currency='USD', localSymbol='ETH.USD', tradingClass='ETH'), order=Order(orderId=8, clientId=91, action='BUY', totalQuantity=1.0, orderType='LMT', lmtPrice=2190, tif='IOC', account='DUH316001'), orderStatus=OrderStatus(orderId=8, status='PendingSubmit', filled=0.0, remaining=0.0, avgFillPrice=0.0, permId=0, parentId=0, lastFillPrice=0.0, clientId=0, whyHeld='', mktCapPrice=0.0), fills=[], log=[TradeLogEntry(time=datetime.datetime(2026, 4, 12, 13, 48, 5, 698466, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='', errorCode=0)], advancedError='')
