# %%
# !pip3 install finvizfinance
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from finvizfinance.quote import finvizfinance

stock = finvizfinance('tsla')

# %%
stock_name=['AMZN','GOOG','MSFT','AAPL']
pe={}
for name in stock_name:
    stock = finvizfinance(name)
    b=stock.ticker_fundament().get('P/E')
    pe.update({name:b})
pe
b=list(pe.values())
stock_name[b.index(max(b))]
# Out:
# 'AAPL'

# %%
stock.ticker_fundament()
# Out:
# {'Company': 'Tesla Inc',
#  'Sector': 'Consumer Cyclical',
#  'Industry': 'Auto Manufacturers',
#  'Country': 'USA',
#  'Exchange': 'NASD',
#  'Index': 'NDX, S&P 500',
#  'P/E': '387.96',
#  'EPS (ttm)': '1.08',
#  'Insider Own': '28.17%',
#  'Shs Outstand': '3.75B',
#  'Perf Week': '1.54%',
#  'Market Cap': '1566.42B',
#  'Forward P/E': '159.48',
#  'EPS next Y': '2.62',
#  'Insider Trans': '0.21%',
#  'Shs Float': '2.39B',
#  'Perf Month': '-4.95%',
#  'Enterprise Value': '1537.41B',
#  'PEG': '5.34',
#  'EPS next Q': '0.42',
#  'Inst Own': '48.78%',
#  'Short Float': '2.69%',
#  'Perf Quarter': '-3.06%',
#  'Income': '3.79B',
#  'P/S': '16.52',
#  'EPS this Y': '19.65%',
#  'Inst Trans': '0.62%',
#  'Short Ratio': '0.90',
#  'Perf Half Y': '24.39%',
#  'Sales': '94.83B',
#  'P/B': '19.06',
#  'EPS next Y Percentage': '31.78%',
#  'ROA': '2.92%',
#  'Short Interest': '64.37M',
#  'Perf YTD': '-7.18%',
#  'Book/sh': '21.90',
#  'P/C': '35.24',
#  'EPS next 5Y': '29.89%',
# ...

# %%
from finvizfinance.screener.overview import Overview

foverview = Overview()
filters_dict = {'Index':'RUSSELL 2000','Sector':'Basic Materials','P/E':'High (>50)','Beta':'Over 1'}
foverview.set_filter(filters_dict=filters_dict)
df = foverview.screener_view()
df.head()
# Out:
#   Ticker                  Company           Sector  \
# 0   CENX      Century Aluminum Co  Basic Materials
# 1     HL          Hecla Mining Co  Basic Materials
# 2    PRM  Perimeter Solutions Inc  Basic Materials
#
#                          Industry Country    Market Cap    P/E  Price  Change  \
# 0                        Aluminum     USA  4.300000e+09  57.65  46.04 -0.0736
# 1  Other Precious Metals & Mining     USA  1.514000e+10  74.44  22.60  0.0819
# 2             Specialty Chemicals     USA  3.880000e+09  62.24  26.22  0.0096
#
#        Volume
# 0   5092341.0
# 1  17133073.0
# 2    751750.0

# %%
df
# Out:
#   Ticker                  Company           Sector  \
# 0   CENX      Century Aluminum Co  Basic Materials
# 1     HL          Hecla Mining Co  Basic Materials
# 2    PRM  Perimeter Solutions Inc  Basic Materials
#
#                          Industry Country    Market Cap    P/E  Price  Change  \
# 0                        Aluminum     USA  4.300000e+09  57.65  46.04 -0.0736
# 1  Other Precious Metals & Mining     USA  1.514000e+10  74.44  22.60  0.0819
# 2             Specialty Chemicals     USA  3.880000e+09  62.24  26.22  0.0096
#
#        Volume
# 0   5092341.0
# 1  17133073.0
# 2    751750.0
