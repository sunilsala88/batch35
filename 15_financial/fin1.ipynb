# %%
#yfinance
import yfinance as yf
data=yf.download('DOT-USD',period='7d',interval='1m',multi_level_index=False,ignore_tz=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                         Close      High       Low      Open  Volume
# Datetime
# 2026-02-08 00:00:00  1.372244  1.372244  1.372244  1.372244       0
# 2026-02-08 00:01:00  1.371988  1.371988  1.371988  1.371988       0
# 2026-02-08 00:02:00  1.371916  1.371916  1.371916  1.371916    7056
# 2026-02-08 00:03:00  1.372043  1.372043  1.372043  1.372043       0
# 2026-02-08 00:04:00  1.371637  1.371637  1.371637  1.371637       0
# ...                       ...       ...       ...       ...     ...
# 2026-02-14 13:05:00  1.363755  1.363755  1.363755  1.363755  181264
# 2026-02-14 13:06:00  1.364058  1.364058  1.364058  1.364058   28080
# 2026-02-14 13:07:00  1.363620  1.363620  1.363620  1.363620   66584
# 2026-02-14 13:09:00  1.363842  1.363842  1.363842  1.363842       0
# 2026-02-14 13:10:00  1.364223  1.364223  1.364223  1.364223   73320
#
# [8205 rows x 5 columns]

# %%
data=yf.download('DOT-USD',start='2024-01-01',end='2024-02-01',interval='1d',multi_level_index=False,ignore_tz=True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Close      High       Low      Open     Volume
# Date
# 2024-01-01  8.598925  8.624625  8.099417  8.201031  246624749
# 2024-01-02  8.412696  8.801247  8.354272  8.599174  340575264
# 2024-01-03  7.641823  8.564529  6.978059  8.412877  662847385
# 2024-01-04  7.881476  7.987429  7.537780  7.641465  333627890
# 2024-01-05  7.445562  7.945946  7.246333  7.881258  348229259
# 2024-01-06  7.138831  7.448601  6.987272  7.445598  241045789
# 2024-01-07  6.895833  7.313965  6.844491  7.139665  223805100
# 2024-01-08  7.477948  7.500977  6.564641  6.896447  344729757
# 2024-01-09  7.117210  7.521773  6.926911  7.478613  293447141
# 2024-01-10  7.971061  8.074016  6.848067  7.118541  416263452
# 2024-01-11  8.170189  8.566725  7.883282  7.973370  535315793
# 2024-01-12  7.569274  8.206327  7.419299  8.166201  350427695
# 2024-01-13  7.612985  7.740000  7.412961  7.567116  202570099
# ...

# %%
stock=yf.Ticker('AMZN')
stock.info
# Out:
# {'address1': '410 Terry Avenue North',
#  'city': 'Seattle',
#  'state': 'WA',
#  'zip': '98109-5210',
#  'country': 'United States',
#  'phone': '206 266 1000',
#  'website': 'https://www.amazon.com',
#  'industry': 'Internet Retail',
#  'industryKey': 'internet-retail',
#  'industryDisp': 'Internet Retail',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
stock_name=['AMZN','GOOG','MSFT','AAPL']
beta={}
for name in stock_name:
    stock=yf.Ticker(name)
    b=stock.info.get('beta')
    beta.update({name:b})
beta
# Out:
# {'AMZN': 1.385, 'GOOG': 1.086, 'MSFT': 1.084, 'AAPL': 1.107}

# %%
b=list(beta.values())
stock_name[b.index(max(b))]
# Out:
# 'AMZN'
