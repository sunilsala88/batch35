# %%
path1=r'/Users/algo trading 2026/batch35/12_pandas/unicorn.csv'
import pandas as pd
df=pd.read_csv(path1)
df
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df['Year Founded']+1
# Out:
# 0       2013
# 1       2003
# 2       2009
# 3       2011
# 4       2006
#         ...
# 1069    2013
# 1070    2016
# 1071    2019
# 1072    2006
# 1073    2015
# Name: Year Founded, Length: 1074, dtype: int64

# %%
l1=[]
for i in df['Year Founded']:
    l1.append(i+1)
df['Year Founded']=l1

# %%
df[df['Valuation']>100]
# Out:
#      Company  Valuation Date Joined                 Industry     City Country  \
# 0  Bytedance        180  2017-04-07  Artificial intelligence  Beijing   China
#
#   Continent  Year Founded  Funding
# 0      Asia          2012      NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1074 non-null   object
#  1   Valuation     1074 non-null   int64
#  2   Date Joined   1074 non-null   datetime64[ns]
#  3   Industry      1074 non-null   object
#  4   City          1058 non-null   object
#  5   Country       1074 non-null   object
#  6   Continent     1074 non-null   object
#  7   Year Founded  1074 non-null   int64
#  8   Funding       1073 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 75.6+ KB

# %%
df[df['Year Founded']>2015]['Company'].to_list()
# Out:
# ['FTX',
#  'Rapyd',
#  'Genki Forest',
#  'Devoted Health',
#  'OpenSea',
#  'Argo AI',
#  'Northvolt',
#  'Faire',
#  'Brex',
#  'Alchemy',
#  'Notion Labs',
#  'Thrasio',
#  'Pony.ai',
#  'Nuro',
#  'Kavak',
#  'Dapper Labs',
#  'Hopin',
#  'Ramp',
#  'Fireblocks',
#  'CRED',
#  'Attentive',
#  'Rippling',
#  'Scale AI',
#  'Ro',
#  'Black Unicorn Factory',
#  'SVOLT',
#  'Deel',
#  'Cityblock Health',
#  'Upgrade',
#  'Better.com',
#  'Wiz',
#  'Anduril',
#  'Cerebral',
#  'OneTrust',
#  'C6 Bank',
#  'Ola Electric Mobility',
#  'Qonto',
#  'SambaNova Systems',
#  'Abogen',
#  'Turing',
#  'MoonPay',
#  'Celsius Network',
#  'Coalition',
#  'Commure',
#  'Flock Safety',
#  'Rec Room',
#  'Tekion',
#  'WeRide',
#  'Applied Intuition',
#  'Papaya Global',
#  'Redwood Materials',
#  'Sorare',
#  'VAST Data',
#  'Dutchie',
#  'FalconX',
#  'dbt Labs',
#  'Relativity Space',
#  'StockX',
#  'Cerebras Systems',
#  'ClickUp',
#  'Clubhouse',
#  'Melio',
#  'Next Insurance',
# ...

# %%
df['Date Joined']=pd.to_datetime(df['Date Joined'],format='%d-%m-%Y')

# %%
df[df['Date Joined'].dt.year==2015]['Company'].to_list()
# Out:
# ['Gusto',
#  'Tanium',
#  'DJI Innovations',
#  'WeDoctor',
#  'Royole Corporation',
#  'Yixia',
#  'Illumio',
#  'Thumbtack',
#  'Tubatu.com',
#  'AppDirect',
#  'TuJia',
#  'Carbon',
#  'Infinidat',
#  'Zhubajie',
#  'WEMAKEPRICE',
#  'Uptake',
#  'ZocDoc',
#  'BlaBlaCar',
#  'Flipboard',
#  'HuJiang',
#  'iTutorGroup',
#  'JimuBox',
#  'LifeMiles',
#  'LinkSure Network',
#  'Apus Group',
#  'Jiuxian',
#  '58 Daojia',
#  'BeiBei',
#  'BenevolentAI',
#  'FXiaoKe',
#  'Lamabang',
#  'Mia.com',
#  'Red Ventures',
#  'Vox Media',
#  'Womai']

# %%
d='06-05-2021'
d1=pd.to_datetime(d,format='%d-%m-%Y')
d1.year
# Out:
# 2021

# %%
import pandas as pd
import requests

url = 'https://en.wikipedia.org/wiki/NIFTY_50'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}

response = requests.get(url, headers=headers)
df7 = pd.read_html(response.text)
data1=df7[1]
data1
# Out:
# /var/folders/gf/2xw81y_n41x8mbjy1d6lp0540000gn/T/ipykernel_41206/2421061468.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df7 = pd.read_html(response.text)
#                        Company name      Symbol  \
# 0                 Adani Enterprises    ADANIENT
# 1                 Adani Ports & SEZ  ADANIPORTS
# 2                  Apollo Hospitals  APOLLOHOSP
# 3                      Asian Paints  ASIANPAINT
# 4                         Axis Bank    AXISBANK
# 5                        Bajaj Auto  BAJAJ-AUTO
# 6                     Bajaj Finance  BAJFINANCE
# 7                     Bajaj Finserv  BAJAJFINSV
# 8                Bharat Electronics         BEL
# 9                     Bharti Airtel  BHARTIARTL
# 10                            Cipla       CIPLA
# 11                       Coal India   COALINDIA
# 12         Dr. Reddy's Laboratories     DRREDDY
# ...

# %%
l1=[]
for i in data1['Date added[16]']:
    if i[-3]=='[':
        l1.append(pd.to_datetime(i[:-3]))
    else:
        l1.append(pd.to_datetime(i))
data1['Date added[16]']=l1

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Company name    50 non-null     object
#  1   Symbol          50 non-null     object
#  2   Sector[15]      50 non-null     object
#  3   Date added[16]  50 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 1.7+ KB

# %%
data1[data1['Date added[16]'].dt.month==3]
# Out:
#               Company name      Symbol                      Sector[15]  \
# 2         Apollo Hospitals  APOLLOHOSP                      Healthcare
# 4                Axis Bank    AXISBANK              Financial Services
# 9            Bharti Airtel  BHARTIARTL               Telecommunication
# 14                 Eternal     ETERNAL               Consumer Services
# 25  Jio Financial Services      JIOFIN              Financial Services
# 30           Maruti Suzuki      MARUTI  Automobile and Auto Components
# 35              Power Grid   POWERGRID                           Power
# 38         Shriram Finance  SHRIRAMFIN              Financial Services
# 42  Tata Consumer Products  TATACONSUM      Fast Moving Consumer Goods
# 45           Tech Mahindra       TECHM          Information Technology
#
#    Date added[16]
# 2      2022-03-31
# 4      2009-03-27
# 9      2004-03-01
# 14     2025-03-28
# 25     2025-03-28
# 30     2004-03-01
# 35     2008-03-14
# 38     2024-03-28
# ...

# %%
data1['Date added[16]'].dt.dayofweek
# Out:
# 0     4
# 1     0
# 2     3
# 3     4
# 4     4
# 5     4
# 6     4
# 7     0
# 8     0
# 9     0
# 10    2
# 11    0
# 12    4
# 13    4
# 14    4
# 15    0
# 16    0
# 17    0
# 18    4
# 19    0
# 20    0
# 21    4
# 22    1
# 23    2
# 24    0
# 25    4
# 26    4
# 27    3
# 28    4
# 29    2
# 30    0
# 31    1
# 32    4
# 33    0
# 34    0
# 35    4
# 36    0
# 37    4
# 38    3
# 39    0
# 40    3
# 41    4
# 42    2
# 43    0
# 44    0
# 45    4
# 46    0
# 47    0
# 48    4
# 49    4
# Name: Date added[16], dtype: int32

# %%
data1['Date added[16]']=pd.to_datetime(data1['Date added[16]'])
