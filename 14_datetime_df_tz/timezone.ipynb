# %%
import datetime as dt
from zoneinfo import ZoneInfo
new_york_timezone = ZoneInfo('America/New_York')
kolkata_timezone = ZoneInfo('Asia/Kolkata')
utc_timezone=ZoneInfo('UTC')
dt1=dt.datetime.now(tz=utc_timezone)
print(dt1)
dt2=dt.datetime.now(tz=new_york_timezone)
print(dt2)
dt3=dt.datetime.now(tz=kolkata_timezone)
print(dt3)
# Out:
# 2026-02-01 13:44:34.237416+00:00
# 2026-02-01 08:44:34.237558-05:00
# 2026-02-01 19:14:34.237606+05:30

# %%
dt2.astimezone(utc_timezone)
# Out:
# datetime.datetime(2026, 2, 1, 13, 44, 34, 237558, tzinfo=zoneinfo.ZoneInfo(key='UTC'))
