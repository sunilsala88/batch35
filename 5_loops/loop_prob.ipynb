# %%
l1=[22,33,44,4,24]
total=0
count=0
#type 1
for i in l1:
    print(i)
    total=total+i
    count=count+1
print(total)
avg=total/count
print(avg)
# Out:
# 22
# 33
# 44
# 4
# 24
# 127
# 25.4

# %%
l1=[22,33,5,4,24]
m=l1[0]
for j in l1:
    if j>m:
        m=j
print(m)
# Out:
# 33
